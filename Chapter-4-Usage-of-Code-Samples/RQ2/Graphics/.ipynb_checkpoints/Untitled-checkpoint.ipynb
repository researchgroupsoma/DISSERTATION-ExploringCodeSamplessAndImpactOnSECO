# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('ggplot')

# %%
df1 = pd.read_csv("android.csv", usecols=[20])

# %%
df2 = pd.read_csv("spring.csv", usecols=[20])

# %%
df1["Questions"] = 1

# %%
df1
# Out:
#     Category  Questions
# 0     Import          1
# 1     Import          1
# 2     Import          1
# 3     Import          1
# 4     Import          1
# ..       ...        ...
# 522  Running          1
# 523  Running          1
# 524  Running          1
# 525  Running          1
# 526  Running          1
#
# [527 rows x 2 columns]

# %%
df2["Questions"] = 1

# %%
df1 = df1.groupby(by="Category").sum()

# %%
df1
# Out:
#            Questions
# Category
# Import            30
# Modify           264
# Reference        170
# Running           63

# %%
df2 = df2.groupby(by="Category").sum()

# %%
df1 = df1.sort_values("Questions")

# %%
df2 = df2.sort_values("Questions")

# %%
df1
# Out:
#            Questions
# Category
# Import            30
# Running           63
# Reference        170
# Modify           264

# %%
df1.to_csv("android_questions.csv")

# %%
df2.to_csv("spring_questions.csv")

# %%
# bar = df.plot(kind="bar", title="Stack Overflow Questions by Category", figsize=(9,8))
# plt.xlabel('Categories', fontsize=20)
# bar.figure.savefig("questions_category_bar.pdf")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# create dummy pandas dataframes


#create subplot figure with having two side by side plots
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
print(axes)
# plot first pandas frame in subplot style
pie1 = df1.plot(ax = axes[0], kind="pie", y="Questions", colormap="tab20c", autopct="%1.1f%%", fontsize=20, figsize=(10,7), legend=False, labeldistance=None) 
pie1.set_title("Android Questions", fontsize=20)
pie1.set_ylabel("")
pie1.legend(labels=["Importing", "Running", "Reference", "Modification"], prop={"size":16}, bbox_to_anchor=(1.45,0.1))

# plot second pandas frame in subplot style
pie2 = df2.plot(ax = axes[1], subplots=False, kind="pie", y="Questions", colormap="tab20c", autopct="%1.1f%%", fontsize=20, figsize=(10,7), legend=False, labeldistance=None)
pie2.set_title("Spring Questions", fontsize=20)
pie2.set_ylabel("")

fig.savefig("questions_category_pie.pdf", bbox_inches="tight")

# %%
pie1 = df1.plot(kind="pie", y="Questions", colormap="tab20c", autopct="%1.1f%%", fontsize=25, figsize=(7,10), legend=True, labeldistance=None)
pie1.set_title("Android Questions", fontsize=30)
pie1.set_ylabel("")
pie1.legend(labels=["Importing", "Running", "Reference", "Modification"], prop={"size":22}, bbox_to_anchor=(0.75,0.1))
# pie1.set_bgcolor("lightslategray")
pie1.figure.savefig("android_questions_category_pie.pdf" )

# %%
pie2 = df2.plot(kind="pie", y="Questions", colormap="tab20c", autopct="%1.1f%%", fontsize=25, figsize=(7,10), legend=False, labeldistance=None)
pie2.set_title("Spring Questions", fontsize=30)
pie2.set_ylabel("")
# pie2.legend(labels=["Importing", "Running", "Reference", "Modification"], prop={"size":22}, bbox_to_anchor=(0.75,0.1))
pie2.figure.savefig("spring_questions_category_pie.pdf")

# %%
pie1 + pie2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-20e136114dbb> in <module>
# ----> 1 pie1 + pie2
#
# TypeError: unsupported operand type(s) for +: 'AxesSubplot' and 'AxesSubplot'
