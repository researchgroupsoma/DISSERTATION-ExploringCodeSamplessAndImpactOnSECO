# %%
import pandas as pd
import github

# %%
g = github.Github("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")

# %%
valid_tuples = pd.read_csv("../5-RepoFilter/output.csv", index_col=0)

# %%
# valid_tuples = valid_tuples.samples(1)

# %%
valid_tuples
# Out:
#             framework                                           sample  \
# 21534   googlearchive               googlearchive/android-instant-apps
# 23797   googlearchive                 googlearchive/leanback-assistant
# 23800   googlearchive                 googlearchive/leanback-assistant
# 37953   googlearchive  googlearchive/android-SynchronizedNotifications
# 38182   googlearchive  googlearchive/android-SynchronizedNotifications
# ...               ...                                              ...
# 374083  googlearchive                googlearchive/android-credentials
# 374233  googlearchive                googlearchive/android-credentials
# 374256  googlearchive                googlearchive/android-credentials
# 374426  googlearchive                googlearchive/android-credentials
# 374712  googlearchive                  googlearchive/android-MidiScope
#
#                  watcher                    watcher_repo
# 21534    xiangjiaowangzi  xiangjiaowangzi/TransitionDemo
# ...

# %%
len(valid_tuples["watcher_repo"].unique())
# Out:
# 686

# %%
dataframe = pd.DataFrame()
cache = dict()
for index in valid_tuples.index:
    print((index/valid_tuples.index[-1])*100)
    repository = valid_tuples.loc[index]
    if (repository["watcher_repo"] in cache.keys()):
        print("Already assessed!")
        continue
    try:
        repo = g.get_repo(repository["watcher_repo"])
    except Exception as e:
        print(e)
    cache[repository["watcher_repo"]] = repo
    objeto = {
        "framework": repository["framework"],
        "sample": repository["sample"],
        "full_name": repo.full_name,
        "archived": repo.archived,
        "created_at": repo.created_at,
        "description": repo.description,
        "forks": repo.forks_count,
        "language": repo.language,
        "open_issues": repo.get_issues(state="open").totalCount,
        "closed_issues": repo.get_issues(state="closed").totalCount,
        "stars": repo.stargazers_count,
        "subscribers": repo.subscribers_count,
        "updated_at": repo.updated_at,
        "watchers": repo.watchers_count,
        "commits": repo.get_commits().totalCount,
        "downloads": repo.get_downloads().totalCount
    }
    objeto["development_time"] = (objeto["updated_at"] - objeto["created_at"]).days
    dataframe = dataframe.append(objeto, ignore_index=True)
# Out:
# 5.7468135528085575
# 6.350744038087919
# 6.35154465296014
# 10.128578748478832
# 10.189692350391768
# 10.19663101261769
# 10.434413629667585
# 10.596404705480476
# 10.830717991417409
# 10.906242661030339
# 10.92865987745255
# 10.954546424987724
# 10.95561391148402
# 10.957482012852537
# 10.958816370972906
# 10.962552573709942
# 10.965221289950682
# 10.966021904822904
# 10.966555648071052
# 11.05142082452657
# 11.059426973248788
# 11.061295074617306
# 11.126678622515424
# 11.266252481906104
# 11.316157475607934
# 13.895471722282712
# 13.933901236149362
# 13.94030615512714
# 13.963523986421572
# 14.111370866158543
# 14.122579474369648
# 14.24800913768441
# 14.380110591601017
# 14.380911206473238
# 14.401727193151007
# 14.508208971156513
# 14.569322573069451
# 17.339450030957106
# 17.50944725549222
# 19.130959243365574
# 21.36120540575162
# 21.45407673092935
# 21.58404321185337
# 21.66090223958667
# 21.662770340955188
# 21.718012767138497
# 22.26403210999381
# 23.3584726403211
# ...

# %%
dataframe.to_csv("output.csv")
