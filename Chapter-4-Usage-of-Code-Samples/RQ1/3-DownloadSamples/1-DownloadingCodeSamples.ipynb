# %% [markdown]
# Loading libraries

# %%
pip install GitPython
# Out:
# Requirement already satisfied: GitPython in c:\programdata\anaconda3\lib\site-packages (3.1.26)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from GitPython) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from git import Repo
import os
import pandas as pd

# %% [markdown]
# Download projects

# %%
def clone(gitUrl, repoDir, sample):
    Repo.clone_from(gitUrl, repoDir + sample)

# %%
def createGitHubUrl(sample):
    return "https://github.com/" + sample + ".git"

# %%
def download(sample):
    gitHubUrl = createGitHubUrl(sample)
    print("Downloading %s" % sample)
    repoDir = "code-samples/"
    isdir = os.path.isdir(repoDir+sample)
    if isdir:
        print("Project " + sample + " previously downloaded")
    else:
        clone(gitHubUrl, repoDir, sample)
        print("%s downloaded" % sample)

# %%
samples = pd.read_csv("../1-GetCodeSamples/codesamples.csv")

# %%
len(samples)
# Out:
# 898

# %%
for i in range (0, len(samples)):
    sample = samples.iloc[i]
    download(sample["full_name"])
# Out:
# Downloading googlesamples/io2014-codelabs
# Project googlesamples/io2014-codelabs previously downloaded
# Downloading googlesamples/android-play-publisher-api
# Project googlesamples/android-play-publisher-api previously downloaded
# Downloading googlesamples/identity-toolkit-java
# Project googlesamples/identity-toolkit-java previously downloaded
# Downloading googlesamples/androidtv-sample-inputs
# Project googlesamples/androidtv-sample-inputs previously downloaded
# Downloading googlesamples/android-AppUsageStatistics
# Project googlesamples/android-AppUsageStatistics previously downloaded
# Downloading googlesamples/android-PermissionRequest
# Project googlesamples/android-PermissionRequest previously downloaded
# Downloading googlesamples/android-testing-templates
# Project googlesamples/android-testing-templates previously downloaded
# Downloading googlesamples/android-play-games-in-motion
# Project googlesamples/android-play-games-in-motion previously downloaded
# Downloading googlesamples/io2015-codelabs
# Project googlesamples/io2015-codelabs previously downloaded
# Downloading googlesamples/google-services
# Project googlesamples/google-services previously downloaded
# Downloading googlesamples/android-testdpc
# Project googlesamples/android-testdpc previously downloaded
# Downloading googlesamples/android-vision
# Project googlesamples/android-vision previously downloaded
# Downloading googlesamples/easypermissions
# Project googlesamples/easypermissions previously downloaded
# Downloading googlesamples/android-play-safetynet
# Project googlesamples/android-play-safetynet previously downloaded
# Downloading googlesamples/testloopmanager
# Project googlesamples/testloopmanager previously downloaded
# Downloading googlesamples/android-TensorFlowCloudMachineLearningEngineStylizer
# Project googlesamples/android-TensorFlowCloudMachineLearningEngineStylizer previously downloaded
# Downloading googlesamples/sceneform-samples
# Project googlesamples/sceneform-samples previously downloaded
# Downloading googlesamples/sceneform-poly-browser
# Project googlesamples/sceneform-poly-browser previously downloaded
# Downloading googlesamples/identity-appflip-tester-android
# Project googlesamples/identity-appflip-tester-android previously downloaded
# Downloading googlesamples/identity-appflip-android
# Project googlesamples/identity-appflip-android previously downloaded
# Downloading googlesamples/glass-enterprise-samples
# Project googlesamples/glass-enterprise-samples previously downloaded
# Downloading googlesamples/mlkit
# Project googlesamples/mlkit previously downloaded
# Downloading googlesamples/gboard-dev-samples
# Project googlesamples/gboard-dev-samples previously downloaded
# Downloading googlesamples/arcore-ml-sample
# Project googlesamples/arcore-ml-sample previously downloaded
# Downloading aws-samples/java-meme-generator-sample
# Project aws-samples/java-meme-generator-sample previously downloaded
# Downloading aws-samples/aws-dynamodb-examples
# Project aws-samples/aws-dynamodb-examples previously downloaded
# Downloading aws-samples/aws-mobile-sample-wif
# Project aws-samples/aws-mobile-sample-wif previously downloaded
# Downloading aws-samples/aws-java-sample
# Project aws-samples/aws-java-sample previously downloaded
# Downloading aws-samples/reinvent2013-mobile-photo-share
# Project aws-samples/reinvent2013-mobile-photo-share previously downloaded
# Downloading aws-samples/aws-big-data-blog
# Project aws-samples/aws-big-data-blog previously downloaded
# Downloading aws-samples/aws-mobile-self-paced-labs-samples
# Project aws-samples/aws-mobile-self-paced-labs-samples previously downloaded
# Downloading aws-samples/amazon-cognito-developer-authentication-sample
# Project aws-samples/amazon-cognito-developer-authentication-sample previously downloaded
# Downloading aws-samples/amazon-kinesis-learning
# Project aws-samples/amazon-kinesis-learning previously downloaded
# Downloading aws-samples/aws-device-farm-sample-app-for-android
# Project aws-samples/aws-device-farm-sample-app-for-android previously downloaded
# Downloading aws-samples/aws-device-farm-appium-tests-for-sample-app
# Project aws-samples/aws-device-farm-appium-tests-for-sample-app previously downloaded
# Downloading aws-samples/aws-codedeploy-sample-tomcat
# Project aws-samples/aws-codedeploy-sample-tomcat previously downloaded
# Downloading aws-samples/aws-device-farm-sample-web-app-using-appium
# Project aws-samples/aws-device-farm-sample-web-app-using-appium previously downloaded
# Downloading aws-samples/eb-tomcat-snakes
# Project aws-samples/eb-tomcat-snakes previously downloaded
# Downloading aws-samples/aws-iotbot
# Project aws-samples/aws-iotbot previously downloaded
# Downloading aws-samples/aws-s3-artifact-manager-sample
# Project aws-samples/aws-s3-artifact-manager-sample previously downloaded
# Downloading aws-samples/lambda-java8-dynamodb
# Project aws-samples/lambda-java8-dynamodb previously downloaded
# Downloading aws-samples/eb-java-scorekeep
# Project aws-samples/eb-java-scorekeep previously downloaded
# Downloading aws-samples/mturk-code-samples
# Project aws-samples/mturk-code-samples previously downloaded
# Downloading aws-samples/aws-photosharing-example
# Project aws-samples/aws-photosharing-example previously downloaded
# Downloading aws-samples/flink-stream-processing-refarch
# Project aws-samples/flink-stream-processing-refarch previously downloaded
# Downloading aws-samples/amazon-ecs-java-microservices
# Project aws-samples/amazon-ecs-java-microservices previously downloaded
# Downloading aws-samples/serverless-codecommit-examples
# Project aws-samples/serverless-codecommit-examples previously downloaded
# Downloading aws-samples/aws-cognito-java-desktop-app
# Project aws-samples/aws-cognito-java-desktop-app previously downloaded
# Downloading aws-samples/blog-multi-region-serverless-service
# Project aws-samples/blog-multi-region-serverless-service previously downloaded
# Downloading aws-samples/ecs-opentracing
# Project aws-samples/ecs-opentracing previously downloaded
# Downloading aws-samples/reactive-refarch-cloudformation
# Project aws-samples/reactive-refarch-cloudformation previously downloaded
# Downloading aws-samples/amazon-cloud-directory-sample
# Project aws-samples/amazon-cloud-directory-sample previously downloaded
# Downloading aws-samples/emr-presto-query-event-listener
# Project aws-samples/emr-presto-query-event-listener previously downloaded
# Downloading aws-samples/amazon-sumerian-arcore-starter-app
# Project aws-samples/amazon-sumerian-arcore-starter-app previously downloaded
# Downloading aws-samples/amazon-workmail-demo-ews-push-notifications
# Project aws-samples/amazon-workmail-demo-ews-push-notifications previously downloaded
# Downloading aws-samples/aws-amazonmq-apachecamel-sample
# Project aws-samples/aws-amazonmq-apachecamel-sample previously downloaded
# Downloading aws-samples/amazon-kinesis-socket-server-sample
# Project aws-samples/amazon-kinesis-socket-server-sample previously downloaded
# Downloading aws-samples/emr-tls-security
# Project aws-samples/emr-tls-security previously downloaded
# Downloading aws-samples/kubernetes-for-java-developers
# Project aws-samples/kubernetes-for-java-developers previously downloaded
# Downloading aws-samples/amazon-mq-workshop
# Project aws-samples/amazon-mq-workshop previously downloaded
# Downloading aws-samples/aws-xray-apache-kafka-sample
# Project aws-samples/aws-xray-apache-kafka-sample previously downloaded
# Downloading aws-samples/aws-dms-cdc-sample
# Project aws-samples/aws-dms-cdc-sample previously downloaded
# Downloading aws-samples/aws-sqlagentjob-to-stepfunctions
# Project aws-samples/aws-sqlagentjob-to-stepfunctions previously downloaded
# Downloading aws-samples/aws-device-farm-appium-cucumber-tests-for-sample-app
# Project aws-samples/aws-device-farm-appium-cucumber-tests-for-sample-app previously downloaded
# Downloading aws-samples/aws-sam-java-rest
# Project aws-samples/aws-sam-java-rest previously downloaded
# Downloading aws-samples/aws-cloudhsm-jce-examples
# Project aws-samples/aws-cloudhsm-jce-examples previously downloaded
# Downloading aws-samples/realtime-bushfire-alert-with-apache-flink-cep
# Project aws-samples/realtime-bushfire-alert-with-apache-flink-cep previously downloaded
# Downloading aws-samples/aws-lambda-sap-oauth
# Project aws-samples/aws-lambda-sap-oauth previously downloaded
# Downloading aws-samples/cloudwatch-agent-demo-custom-metrics
# Project aws-samples/cloudwatch-agent-demo-custom-metrics previously downloaded
# Downloading aws-samples/iot-reference-architectures
# Project aws-samples/iot-reference-architectures previously downloaded
# Downloading aws-samples/aws-blog-athena-custom-jdbc-credentials
# Project aws-samples/aws-blog-athena-custom-jdbc-credentials previously downloaded
# Downloading aws-samples/aws-transcribe-streaming-example-java
# Project aws-samples/aws-transcribe-streaming-example-java previously downloaded
# Downloading aws-samples/reinvent-2018-social-news-app
# Project aws-samples/reinvent-2018-social-news-app previously downloaded
# Downloading aws-samples/aws-greengrass-lambda-functions
# Project aws-samples/aws-greengrass-lambda-functions previously downloaded
# Downloading aws-samples/amazon-sqs-java-temporary-queues-client-samples
# Project aws-samples/amazon-sqs-java-temporary-queues-client-samples previously downloaded
# Downloading aws-samples/amazon-rds-data-api-demo
# Project aws-samples/amazon-rds-data-api-demo previously downloaded
# Downloading aws-samples/amazon-kinesis-replay
# Project aws-samples/amazon-kinesis-replay previously downloaded
# Downloading aws-samples/crud4dynamo
# Project aws-samples/crud4dynamo previously downloaded
# Downloading aws-samples/aws-cloudhsm-on-aws-lambda-sample
# Project aws-samples/aws-cloudhsm-on-aws-lambda-sample previously downloaded
# Downloading aws-samples/amazon-kinesis-analytics-taxi-consumer
# Project aws-samples/amazon-kinesis-analytics-taxi-consumer previously downloaded
# Downloading aws-samples/alexa-web-information-service-api-samples
# Project aws-samples/alexa-web-information-service-api-samples previously downloaded
# Downloading aws-samples/alexa-top-sites-api-samples
# Project aws-samples/alexa-top-sites-api-samples previously downloaded
# Downloading aws-samples/aws-service-catalog-terraform-reference-architecture
# Project aws-samples/aws-service-catalog-terraform-reference-architecture previously downloaded
# Downloading aws-samples/amazon-emr-optimize-data-processing
# Project aws-samples/amazon-emr-optimize-data-processing previously downloaded
# Downloading aws-samples/amazon-kinesis-data-analytics-java-examples
# Project aws-samples/amazon-kinesis-data-analytics-java-examples previously downloaded
# Downloading aws-samples/amazon-polly-mp3-for-microsoft-word
# Project aws-samples/amazon-polly-mp3-for-microsoft-word previously downloaded
# Downloading aws-samples/amazon-kinesis-data-analytics-flinktableapi
# Project aws-samples/amazon-kinesis-data-analytics-flinktableapi previously downloaded
# Downloading aws-samples/aws-saas-factory-postgresql-rls
# Project aws-samples/aws-saas-factory-postgresql-rls previously downloaded
# Downloading aws-samples/amazon-kinesis-analytics-beam-taxi-consumer
# Project aws-samples/amazon-kinesis-analytics-beam-taxi-consumer previously downloaded
# Downloading aws-samples/amazon-mq-migration-from-ibm-mq
# Project aws-samples/amazon-mq-migration-from-ibm-mq previously downloaded
# Downloading aws-samples/aws-codebuild-polyglot-application
# Project aws-samples/aws-codebuild-polyglot-application previously downloaded
# Downloading aws-samples/amazon-qldb-dmv-sample-java
# Project aws-samples/amazon-qldb-dmv-sample-java previously downloaded
# Downloading aws-samples/aws-kms-pq-tls-example
# Project aws-samples/aws-kms-pq-tls-example previously downloaded
# Downloading aws-samples/amazon-textract-searchable-pdf
# Project aws-samples/amazon-textract-searchable-pdf previously downloaded
# Downloading aws-samples/amazon-comprehend-medical-fhir-integration
# Project aws-samples/amazon-comprehend-medical-fhir-integration previously downloaded
# Downloading aws-samples/amazon-chime-voiceconnector-transcription
# Project aws-samples/amazon-chime-voiceconnector-transcription previously downloaded
# Downloading aws-samples/rds-breakglass-user-management
# Project aws-samples/rds-breakglass-user-management previously downloaded
# Downloading aws-samples/busy-engineers-document-bucket
# Project aws-samples/busy-engineers-document-bucket previously downloaded
# Downloading aws-samples/amazon-dynamodb-implementing-priority-queuing
# Project aws-samples/amazon-dynamodb-implementing-priority-queuing previously downloaded
# Downloading aws-samples/faster-cryptography-in-java-with-aws
# Project aws-samples/faster-cryptography-in-java-with-aws previously downloaded
# Downloading aws-samples/aws-glue-data-catalog-replication-utility
# Project aws-samples/aws-glue-data-catalog-replication-utility previously downloaded
# Downloading aws-samples/amazon-eks-jenkins-terraform
# Project aws-samples/amazon-eks-jenkins-terraform previously downloaded
# Downloading aws-samples/aws-codecommit-pull-request-approver-demo
# Project aws-samples/aws-codecommit-pull-request-approver-demo previously downloaded
# Downloading aws-samples/aws-lambda-java-oracle-starter-kit
# Project aws-samples/aws-lambda-java-oracle-starter-kit previously downloaded
# Downloading aws-samples/designing-cloud-native-microservices-on-aws
# Project aws-samples/designing-cloud-native-microservices-on-aws previously downloaded
# Downloading aws-samples/aws-quarkus-demo
# Project aws-samples/aws-quarkus-demo previously downloaded
# Downloading aws-samples/rds-ssl-update
# Project aws-samples/rds-ssl-update previously downloaded
# Downloading aws-samples/amazon-qldb-double-entry-sample-java
# Project aws-samples/amazon-qldb-double-entry-sample-java previously downloaded
# Downloading aws-samples/aws-sdk-js-tests
# Project aws-samples/aws-sdk-js-tests previously downloaded
# Downloading aws-samples/amazon-athena-train-amazon-sagemaker
# Project aws-samples/amazon-athena-train-amazon-sagemaker previously downloaded
# Downloading aws-samples/amazon-kinesis-analytics-streaming-etl
# Project aws-samples/amazon-kinesis-analytics-streaming-etl previously downloaded
# Downloading aws-samples/s3-select-phonebook-search
# Project aws-samples/s3-select-phonebook-search previously downloaded
# Downloading aws-samples/amazon-automated-forecast
# Project aws-samples/amazon-automated-forecast previously downloaded
# Downloading aws-samples/diy-code-signing-kms-private-ca
# Project aws-samples/diy-code-signing-kms-private-ca previously downloaded
# Downloading aws-samples/aws-sigv4-auth-cassandra-java-driver-examples
# Project aws-samples/aws-sigv4-auth-cassandra-java-driver-examples previously downloaded
# Downloading aws-samples/aws-codeguru-profiler-demo-application
# Project aws-samples/aws-codeguru-profiler-demo-application previously downloaded
# Downloading aws-samples/amazon-cloudwatch-monitor-for-sap-netweaver
# Project aws-samples/amazon-cloudwatch-monitor-for-sap-netweaver previously downloaded
# Downloading aws-samples/amazon-msk-client-authentication
# Project aws-samples/amazon-msk-client-authentication previously downloaded
# Downloading aws-samples/aws-trusted-advisor-co-aggregator
# Project aws-samples/aws-trusted-advisor-co-aggregator previously downloaded
# Downloading aws-samples/amazon-codeguru-reviewer-sample-app
# Project aws-samples/amazon-codeguru-reviewer-sample-app previously downloaded
# Downloading aws-samples/aws-ingesting-click-logs-using-terraform
# Project aws-samples/aws-ingesting-click-logs-using-terraform previously downloaded
# Downloading aws-samples/jsii-native-java
# Project aws-samples/jsii-native-java previously downloaded
# Downloading aws-samples/jsii-java-benchmarking
# Project aws-samples/jsii-java-benchmarking previously downloaded
# Downloading aws-samples/k8s-rbac-iam-java-operator
# Project aws-samples/k8s-rbac-iam-java-operator previously downloaded
# Downloading aws-samples/redshift-jdbc-plugin-for-siteminder
# Project aws-samples/redshift-jdbc-plugin-for-siteminder previously downloaded
# Downloading aws-samples/kda-metrics-dashboard
# Project aws-samples/kda-metrics-dashboard previously downloaded
# Downloading aws-samples/aws-dms-msk-demo
# Project aws-samples/aws-dms-msk-demo previously downloaded
# Downloading aws-samples/amazon-mq-fifo-starter-kit
# Project aws-samples/amazon-mq-fifo-starter-kit previously downloaded
# Downloading aws-samples/amazon-kinesis-low-level-producer-sample
# Project aws-samples/amazon-kinesis-low-level-producer-sample previously downloaded
# Downloading aws-samples/mirrormaker2-msk-migration
# Project aws-samples/mirrormaker2-msk-migration previously downloaded
# Downloading aws-samples/clickstream-consumer-for-apache-kafka
# Project aws-samples/clickstream-consumer-for-apache-kafka previously downloaded
# Downloading aws-samples/clickstream-producer-for-apache-kafka
# Project aws-samples/clickstream-producer-for-apache-kafka previously downloaded
# Downloading aws-samples/aws-saas-factory-ref-solution-metrics-analytics
# Project aws-samples/aws-saas-factory-ref-solution-metrics-analytics previously downloaded
# Downloading aws-samples/pix-proxy-samples
# Project aws-samples/pix-proxy-samples previously downloaded
# Downloading aws-samples/amazon-aurora-mysql-with-mariadb-jdbc-driver
# Project aws-samples/amazon-aurora-mysql-with-mariadb-jdbc-driver previously downloaded
# Downloading aws-samples/amazon-unified-streaming-etl
# Project aws-samples/amazon-unified-streaming-etl previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-common
# Project aws-samples/bcs-disaster-recovery-portal-common previously downloaded
# Downloading aws-samples/lambda-java-blockchain
# Project aws-samples/lambda-java-blockchain previously downloaded
# Downloading aws-samples/aws-iot-proxy-mobile-app-android
# Project aws-samples/aws-iot-proxy-mobile-app-android previously downloaded
# Downloading aws-samples/aws-kms-jce
# Project aws-samples/aws-kms-jce previously downloaded
# Downloading aws-samples/aws-expense-handling-workflow
# Project aws-samples/aws-expense-handling-workflow previously downloaded
# Downloading aws-samples/iot-all-the-things-special-projects-edition
# Project aws-samples/iot-all-the-things-special-projects-edition previously downloaded
# Downloading aws-samples/aws-saas-factory-dynamic-policy-generation
# Project aws-samples/aws-saas-factory-dynamic-policy-generation previously downloaded
# Downloading aws-samples/serverless-webapp-mono-repo-ci-cd-java
# Project aws-samples/serverless-webapp-mono-repo-ci-cd-java previously downloaded
# Downloading aws-samples/saas-tenant-isolation-architecture
# Project aws-samples/saas-tenant-isolation-architecture previously downloaded
# Downloading aws-samples/amazon-kinesis-data-analytics-flink-starter-kit
# Project aws-samples/amazon-kinesis-data-analytics-flink-starter-kit previously downloaded
# Downloading aws-samples/integration-sample-lambda-msk
# Project aws-samples/integration-sample-lambda-msk previously downloaded
# Downloading aws-samples/aws-transcribe-speaker-identification-java
# Project aws-samples/aws-transcribe-speaker-identification-java previously downloaded
# Downloading aws-samples/k8s-cloudwatch-operator
# Project aws-samples/k8s-cloudwatch-operator previously downloaded
# Downloading aws-samples/amazon-kinesis-data-analytics-flink-benchmarking-utility
# Project aws-samples/amazon-kinesis-data-analytics-flink-benchmarking-utility previously downloaded
# Downloading aws-samples/aws-lambda-servlet
# Project aws-samples/aws-lambda-servlet previously downloaded
# Downloading aws-samples/amazon-chime-voice-connector-automated-reports
# Project aws-samples/amazon-chime-voice-connector-automated-reports previously downloaded
# Downloading aws-samples/building-java-apps-using-code-pipeline
# Project aws-samples/building-java-apps-using-code-pipeline previously downloaded
# Downloading aws-samples/amazon-athena-serverless-ehms-connector
# Project aws-samples/amazon-athena-serverless-ehms-connector previously downloaded
# Downloading aws-samples/efo-ltr-flink-sample
# Project aws-samples/efo-ltr-flink-sample previously downloaded
# Downloading aws-samples/machinelearning-amazonai-amazontranscribe
# Project aws-samples/machinelearning-amazonai-amazontranscribe previously downloaded
# Downloading aws-samples/single-use-signed-url
# Project aws-samples/single-use-signed-url previously downloaded
# Downloading aws-samples/aws-glue-table-versions-cleanup-utility
# Project aws-samples/aws-glue-table-versions-cleanup-utility previously downloaded
# Downloading aws-samples/api-gateway-auth
# Project aws-samples/api-gateway-auth previously downloaded
# Downloading aws-samples/amazon-resilient-fix-engine-demo
# Project aws-samples/amazon-resilient-fix-engine-demo previously downloaded
# Downloading aws-samples/aws-appconfig-java-sample
# Project aws-samples/aws-appconfig-java-sample previously downloaded
# Downloading aws-samples/comprehend-logging-redact
# Project aws-samples/comprehend-logging-redact previously downloaded
# Downloading aws-samples/kinesis-data-analytics-flink-aurora-sink
# Project aws-samples/kinesis-data-analytics-flink-aurora-sink previously downloaded
# Downloading aws-samples/integrate-amazon-connect-with-smart-on-fhir-backend-services
# Project aws-samples/integrate-amazon-connect-with-smart-on-fhir-backend-services previously downloaded
# Downloading aws-samples/sasl-scram-secrets-manager-client-for-msk
# Project aws-samples/sasl-scram-secrets-manager-client-for-msk previously downloaded
# Downloading aws-samples/aws-saas-factory-eks-reference-architecture
# Project aws-samples/aws-saas-factory-eks-reference-architecture previously downloaded
# Downloading aws-samples/aws-cdk-constructs-for-java
# Project aws-samples/aws-cdk-constructs-for-java previously downloaded
# Downloading aws-samples/cookiecutter-aws-sam-powertools-java
# Project aws-samples/cookiecutter-aws-sam-powertools-java previously downloaded
# Downloading aws-samples/aws-saas-factory-billing-and-metering-reference-implementation
# Project aws-samples/aws-saas-factory-billing-and-metering-reference-implementation previously downloaded
# Downloading aws-samples/amazon-keyspaces-large-object-s3-demo
# Project aws-samples/amazon-keyspaces-large-object-s3-demo previously downloaded
# Downloading aws-samples/amazon-transcribe-email-workflow
# Project aws-samples/amazon-transcribe-email-workflow previously downloaded
# Downloading aws-samples/amazon-managed-blockchain-client-provision-with-cdk-java
# Project aws-samples/amazon-managed-blockchain-client-provision-with-cdk-java previously downloaded
# Downloading aws-samples/selling-partner-api-bootstrap
# Project aws-samples/selling-partner-api-bootstrap previously downloaded
# Downloading aws-samples/jasper-reports-with-lambda-rds
# Project aws-samples/jasper-reports-with-lambda-rds previously downloaded
# Downloading aws-samples/amazon-keyspaces-examples
# Project aws-samples/amazon-keyspaces-examples previously downloaded
# Downloading aws-samples/amazon-connect-collect-feedback-via-phone-ivr
# Project aws-samples/amazon-connect-collect-feedback-via-phone-ivr previously downloaded
# Downloading aws-samples/immutable-server-pipeline
# Project aws-samples/immutable-server-pipeline previously downloaded
# Downloading aws-samples/private-link-cross-account-access-for-msk
# Project aws-samples/private-link-cross-account-access-for-msk previously downloaded
# Downloading aws-samples/amazon-kinesis-video-streams-media-screencast-android
# Project aws-samples/amazon-kinesis-video-streams-media-screencast-android previously downloaded
# Downloading aws-samples/amazon-lex-twilio-voice-integration
# Project aws-samples/amazon-lex-twilio-voice-integration previously downloaded
# Downloading aws-samples/kinesis-data-analytics-apache-flink-async-io
# Project aws-samples/kinesis-data-analytics-apache-flink-async-io previously downloaded
# Downloading aws-samples/amazon-ecs-and-aws-step-functions-design-patterns-starter-kit
# Project aws-samples/amazon-ecs-and-aws-step-functions-design-patterns-starter-kit previously downloaded
# Downloading aws-samples/aws-amplify-android-simple-app
# Project aws-samples/aws-amplify-android-simple-app previously downloaded
# Downloading aws-samples/amazon-codeguru-samples
# Project aws-samples/amazon-codeguru-samples previously downloaded
# Downloading aws-samples/aws-athena-udfs-textanalytics
# Project aws-samples/aws-athena-udfs-textanalytics previously downloaded
# Downloading aws-samples/amazon-textract-comprehend-stepfunctions-example
# Project aws-samples/amazon-textract-comprehend-stepfunctions-example previously downloaded
# Downloading aws-samples/amazon-keyspaces-java-driver-helpers
# Project aws-samples/amazon-keyspaces-java-driver-helpers previously downloaded
# Downloading aws-samples/cdk-lambda-packaging-java
# Project aws-samples/cdk-lambda-packaging-java previously downloaded
# Downloading aws-samples/amazon-s3-object-lambda-decompression
# Project aws-samples/amazon-s3-object-lambda-decompression previously downloaded
# Downloading aws-samples/skiresort-example-dynamodb-aws-sdk-v1
# Project aws-samples/skiresort-example-dynamodb-aws-sdk-v1 previously downloaded
# Downloading aws-samples/amazon-msk-java-app-cdk
# Project aws-samples/amazon-msk-java-app-cdk previously downloaded
# Downloading aws-samples/sub-minute-lambda-executor
# Project aws-samples/sub-minute-lambda-executor previously downloaded
# Downloading aws-samples/amazon-elasticache-redis-and-memcached-java-client-examples
# Project aws-samples/amazon-elasticache-redis-and-memcached-java-client-examples previously downloaded
# Downloading aws-samples/amazon-sqs-message-attributes-starter-kit
# Project aws-samples/amazon-sqs-message-attributes-starter-kit previously downloaded
# Downloading aws-samples/amazon-sagemaker-feature-store-in-java
# Project aws-samples/amazon-sagemaker-feature-store-in-java previously downloaded
# Downloading aws-samples/build-and-deploy-docker-images-to-aws-using-ec2-image-builder
# Project aws-samples/build-and-deploy-docker-images-to-aws-using-ec2-image-builder previously downloaded
# Downloading aws-samples/i-love-my-local-farmer
# Project aws-samples/i-love-my-local-farmer previously downloaded
# Downloading aws-samples/amazon-msk-with-apache-kafka-streams-api
# Project aws-samples/amazon-msk-with-apache-kafka-streams-api previously downloaded
# Downloading aws-samples/aws-serverless-stack-to-parse-apache-orc-files
# Project aws-samples/aws-serverless-stack-to-parse-apache-orc-files previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-server
# Project aws-samples/bcs-disaster-recovery-portal-server previously downloaded
# Downloading aws-samples/bcs-cloud-endure-common
# Project aws-samples/bcs-cloud-endure-common previously downloaded
# Downloading aws-samples/bcs-cloud-endure-service
# Project aws-samples/bcs-cloud-endure-service previously downloaded
# Downloading aws-samples/bcs-cloud-formation
# Project aws-samples/bcs-cloud-formation previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-formation
# Project aws-samples/bcs-disaster-recovery-portal-formation previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-s3
# Project aws-samples/bcs-disaster-recovery-portal-s3 previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-lambda-base
# Project aws-samples/bcs-disaster-recovery-portal-lambda-base previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-cloud-endure
# Project aws-samples/bcs-disaster-recovery-portal-cloud-endure previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-lambda
# Project aws-samples/bcs-disaster-recovery-portal-lambda previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-vpc
# Project aws-samples/bcs-disaster-recovery-portal-vpc previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-dynamodb
# Project aws-samples/bcs-disaster-recovery-portal-dynamodb previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-dynamodb-stream
# Project aws-samples/bcs-disaster-recovery-portal-dynamodb-stream previously downloaded
# Downloading aws-samples/bcs-disaster-recovery-portal-mysql-dump
# Project aws-samples/bcs-disaster-recovery-portal-mysql-dump previously downloaded
# Downloading aws-samples/amazon-keyspaces-spring-app-example
# Project aws-samples/amazon-keyspaces-spring-app-example previously downloaded
# Downloading aws-samples/ecs-windows-ci-cd-blue-green
# Project aws-samples/ecs-windows-ci-cd-blue-green previously downloaded
# Downloading aws-samples/aws-amplify-example-recipe-app-react-native
# Project aws-samples/aws-amplify-example-recipe-app-react-native previously downloaded
# Downloading aws-samples/aws-iot-job-agent-android
# Project aws-samples/aws-iot-job-agent-android previously downloaded
# Downloading aws-samples/s3-parallel-move-with-filtering
# Project aws-samples/s3-parallel-move-with-filtering previously downloaded
# Downloading aws-samples/aws-apprunner-terraform
# Project aws-samples/aws-apprunner-terraform previously downloaded
# Downloading aws-samples/graceful-shutdown-with-aws-lambda
# Project aws-samples/graceful-shutdown-with-aws-lambda previously downloaded
# Downloading aws-samples/aws-cdk-codeartifact-pipeline-sample
# Project aws-samples/aws-cdk-codeartifact-pipeline-sample previously downloaded
# Downloading aws-samples/amazon-kinesis-data-analytics-apache-flink-server-sent-events-sse
# Project aws-samples/amazon-kinesis-data-analytics-apache-flink-server-sent-events-sse previously downloaded
# Downloading aws-samples/aws-lambda-powertools-examples
# Project aws-samples/aws-lambda-powertools-examples previously downloaded
# Downloading aws-samples/aws-lambda-java-tiered-compilation-example
# Project aws-samples/aws-lambda-java-tiered-compilation-example previously downloaded
# Downloading aws-samples/multi-environment-chatops-bot-for-controltower
# Project aws-samples/multi-environment-chatops-bot-for-controltower previously downloaded
# Downloading aws-samples/flink-clickstream-processor-msk
# Project aws-samples/flink-clickstream-processor-msk previously downloaded
# Downloading aws-samples/amazon-ecs-cicd-cdk
# Project aws-samples/amazon-ecs-cicd-cdk previously downloaded
# Downloading aws-samples/java-sample-app
# Project aws-samples/java-sample-app previously downloaded
# Downloading aws-samples/aws-cloudformation-stack-instances
# Project aws-samples/aws-cloudformation-stack-instances previously downloaded
# Downloading aws-samples/aws-fargate-server-sent-events-sse-amazon-kinesis-data-streams
# Project aws-samples/aws-fargate-server-sent-events-sse-amazon-kinesis-data-streams previously downloaded
# Downloading aws-samples/aws-redshift-udfs-textanalytics
# Project aws-samples/aws-redshift-udfs-textanalytics previously downloaded
# Downloading aws-samples/java-spring-boot-ecs-fargate-redis-caching
# Project aws-samples/java-spring-boot-ecs-fargate-redis-caching previously downloaded
# Downloading aws-samples/aws-organizations-account-resource
# Project aws-samples/aws-organizations-account-resource previously downloaded
# Downloading aws-samples/aws-concurrent-provisioned-product
# Project aws-samples/aws-concurrent-provisioned-product previously downloaded
# Downloading aws-samples/exporting-tool-for-amazon-keyspaces
# Project aws-samples/exporting-tool-for-amazon-keyspaces previously downloaded
# Downloading aws-samples/amazon-s3-object-lambda-default-configuration
# Project aws-samples/amazon-s3-object-lambda-default-configuration previously downloaded
# Downloading aws-samples/java-crud-microservice-template
# Project aws-samples/java-crud-microservice-template previously downloaded
# Downloading aws-samples/aws-kcl-java
# aws-samples/aws-kcl-java downloaded
# Downloading aws-samples/sns-dynamic-subscribers
# aws-samples/sns-dynamic-subscribers downloaded
# Downloading aws-samples/aws-msk-cross-account-glue-schema-registry
# aws-samples/aws-msk-cross-account-glue-schema-registry downloaded
# Downloading aws-samples/amazon-pinpoint-urlshortener
# aws-samples/amazon-pinpoint-urlshortener downloaded
# Downloading aws-samples/amazon-redshift-devops-blog
# aws-samples/amazon-redshift-devops-blog downloaded
# Downloading aws-samples/azure-eventhub-consumer-with-dynamodb
# aws-samples/azure-eventhub-consumer-with-dynamodb downloaded
# Downloading aws-samples/cost-optimized-flink-on-kubernetes
# aws-samples/cost-optimized-flink-on-kubernetes downloaded
# Downloading aws-samples/aws-blog-observability-platform
# aws-samples/aws-blog-observability-platform downloaded
# Downloading aws-samples/aws-ecs-springboot-opentelemetry-sample
# aws-samples/aws-ecs-springboot-opentelemetry-sample downloaded
# Downloading aws-samples/aws-kinesis-data-streams-replicator
# aws-samples/aws-kinesis-data-streams-replicator downloaded
# Downloading aws-samples/aws-glue-schema-registry-examples
# aws-samples/aws-glue-schema-registry-examples downloaded
# Downloading aws-samples/serverless-graalvm-demo
# aws-samples/serverless-graalvm-demo downloaded
# Downloading aws-samples/aws-appconfig-with-quarkus
# aws-samples/aws-appconfig-with-quarkus downloaded
# Downloading aws-samples/aws-mq-network-of-brokers
# aws-samples/aws-mq-network-of-brokers downloaded
# Downloading aws-samples/amazon-codeguru-reviewer-java-detectors
# aws-samples/amazon-codeguru-reviewer-java-detectors downloaded
# Downloading aws-samples/polly-translate-realtime-speech-translator
# aws-samples/polly-translate-realtime-speech-translator downloaded
# Downloading aws-samples/amazon-s3-access-points-for-cross-account-integration-samples
# aws-samples/amazon-s3-access-points-for-cross-account-integration-samples downloaded
# Downloading aws-samples/flink-industrial-anomaly-detector
# aws-samples/flink-industrial-anomaly-detector downloaded
# Downloading aws-samples/aws-mqtt-wavelength-latency
# aws-samples/aws-mqtt-wavelength-latency downloaded
# Downloading aws-samples/aws-sns-subscription-cleaner
# aws-samples/aws-sns-subscription-cleaner downloaded
# Downloading aws-samples/aws-big-data-blog-transactional-to-stateful-batch-processing
# aws-samples/aws-big-data-blog-transactional-to-stateful-batch-processing downloaded
# Downloading aws-samples/amazon-appflow-custom-jdbc-connector
# aws-samples/amazon-appflow-custom-jdbc-connector downloaded
# Downloading Azure-Samples/active-directory-android
# Azure-Samples/active-directory-android downloaded
# Downloading Azure-Samples/storage-blob-java-getting-started
# Azure-Samples/storage-blob-java-getting-started downloaded
# Downloading Azure-Samples/storage-table-java-getting-started
# Azure-Samples/storage-table-java-getting-started downloaded
# Downloading Azure-Samples/storage-queue-java-getting-started
# Azure-Samples/storage-queue-java-getting-started downloaded
# Downloading Azure-Samples/documentdb-java-todo-app
# Azure-Samples/documentdb-java-todo-app downloaded
# Downloading Azure-Samples/storage-file-java-getting-started
# Azure-Samples/storage-file-java-getting-started downloaded
# Downloading Azure-Samples/search-java-getting-started
# Azure-Samples/search-java-getting-started downloaded
# Downloading Azure-Samples/active-directory-java-webapp-openidconnect
# Azure-Samples/active-directory-java-webapp-openidconnect downloaded
# Downloading Azure-Samples/app-service-api-apps-quickstart-java
# Azure-Samples/app-service-api-apps-quickstart-java downloaded
# Downloading Azure-Samples/hdinsight-storm-azure-data-lake-store
# Azure-Samples/hdinsight-storm-azure-data-lake-store downloaded
# Downloading Azure-Samples/hdinsight-java-storm-wordcount
# Azure-Samples/hdinsight-java-storm-wordcount downloaded
# Downloading Azure-Samples/hdinsight-java-hive-jdbc
# Azure-Samples/hdinsight-java-hive-jdbc downloaded
# Downloading Azure-Samples/hdinsight-java-storm-eventhub
# Azure-Samples/hdinsight-java-storm-eventhub downloaded
# Downloading Azure-Samples/active-directory-android-native-oidcandroidlib-v2
# Azure-Samples/active-directory-android-native-oidcandroidlib-v2 downloaded
# Downloading Azure-Samples/compute-java-manage-vm
# Azure-Samples/compute-java-manage-vm downloaded
# Downloading Azure-Samples/storage-java-manage-storage-accounts
# Azure-Samples/storage-java-manage-storage-accounts downloaded
# Downloading Azure-Samples/network-java-manage-network-security-group
# Azure-Samples/network-java-manage-network-security-group downloaded
# Downloading Azure-Samples/compute-java-list-vm-images
# Azure-Samples/compute-java-list-vm-images downloaded
# Downloading Azure-Samples/resources-java-manage-resource-group
# Azure-Samples/resources-java-manage-resource-group downloaded
# Downloading Azure-Samples/resources-java-deploy-using-arm-template-with-progress
# Azure-Samples/resources-java-deploy-using-arm-template-with-progress downloaded
# Downloading Azure-Samples/compute-java-manage-availability-sets
# Azure-Samples/compute-java-manage-availability-sets downloaded
# Downloading Azure-Samples/network-java-manage-virtual-network
# Azure-Samples/network-java-manage-virtual-network downloaded
# Downloading Azure-Samples/network-java-manage-ip-address
# Azure-Samples/network-java-manage-ip-address downloaded
# Downloading Azure-Samples/resources-java-manage-resource
# Azure-Samples/resources-java-manage-resource downloaded
# Downloading Azure-Samples/network-java-manage-network-interface
# Azure-Samples/network-java-manage-network-interface downloaded
# Downloading Azure-Samples/resources-java-deploy-using-arm-template
# Azure-Samples/resources-java-deploy-using-arm-template downloaded
# Downloading Azure-Samples/hdinsight-java-deploy-storm-topology
# Azure-Samples/hdinsight-java-deploy-storm-topology downloaded
# Downloading Azure-Samples/hdinsight-java-hive-udf
# Azure-Samples/hdinsight-java-hive-udf downloaded
# Downloading Azure-Samples/hdinsight-storm-java-kafka
# Azure-Samples/hdinsight-storm-java-kafka downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machines-in-parallel
# Azure-Samples/compute-java-manage-virtual-machines-in-parallel downloaded
# Downloading Azure-Samples/batch-java-manage-batch-accounts
# Azure-Samples/batch-java-manage-batch-accounts downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machine-using-vm-extensions
# Azure-Samples/compute-java-manage-virtual-machine-using-vm-extensions downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machines-with-network-in-parallel
# Azure-Samples/compute-java-manage-virtual-machines-with-network-in-parallel downloaded
# Downloading Azure-Samples/network-java-manage-internet-facing-load-balancers
# Azure-Samples/network-java-manage-internet-facing-load-balancers downloaded
# Downloading Azure-Samples/key-vault-java-manage-key-vaults
# Azure-Samples/key-vault-java-manage-key-vaults downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machine-scale-sets
# Azure-Samples/compute-java-manage-virtual-machine-scale-sets downloaded
# Downloading Azure-Samples/network-java-manage-internal-load-balancers
# Azure-Samples/network-java-manage-internal-load-balancers downloaded
# Downloading Azure-Samples/compute-java-list-vm-extension-images
# Azure-Samples/compute-java-list-vm-extension-images downloaded
# Downloading Azure-Samples/data-lake-store-java-upload-download-get-started
# Azure-Samples/data-lake-store-java-upload-download-get-started downloaded
# Downloading Azure-Samples/storage-blob-android-photo-uploader
# Azure-Samples/storage-blob-android-photo-uploader downloaded
# Downloading Azure-Samples/event-hubs-java-storm-sender-jms-receiver
# Azure-Samples/event-hubs-java-storm-sender-jms-receiver downloaded
# Downloading Azure-Samples/hdinsight-kafka-java-get-started
# Azure-Samples/hdinsight-kafka-java-get-started downloaded
# Downloading Azure-Samples/storage-java-client-side-encryption
# Azure-Samples/storage-java-client-side-encryption downloaded
# Downloading Azure-Samples/app-service-java-manage-storage-connections-for-web-apps
# Azure-Samples/app-service-java-manage-storage-connections-for-web-apps downloaded
# Downloading Azure-Samples/sql-database-java-manage-sql-dbs-in-elastic-pool
# Azure-Samples/sql-database-java-manage-sql-dbs-in-elastic-pool downloaded
# Downloading Azure-Samples/sql-database-java-manage-firewalls-for-sql-databases
# Azure-Samples/sql-database-java-manage-firewalls-for-sql-databases downloaded
# Downloading Azure-Samples/compute-java-create-virtual-machines-across-regions-in-parallel
# Azure-Samples/compute-java-create-virtual-machines-across-regions-in-parallel downloaded
# Downloading Azure-Samples/sql-database-java-manage-sql-databases-across-regions
# Azure-Samples/sql-database-java-manage-sql-databases-across-regions downloaded
# Downloading Azure-Samples/dns-java-host-and-manage-your-domains
# Azure-Samples/dns-java-host-and-manage-your-domains downloaded
# Downloading Azure-Samples/redis-java-manage-cache
# Azure-Samples/redis-java-manage-cache downloaded
# Downloading Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps
# Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps downloaded
# Downloading Azure-Samples/sql-database-java-manage-db
# Azure-Samples/sql-database-java-manage-db downloaded
# Downloading Azure-Samples/app-service-java-manage-staging-and-production-slots-for-web-apps
# Azure-Samples/app-service-java-manage-staging-and-production-slots-for-web-apps downloaded
# Downloading Azure-Samples/traffic-manager-java-manage-profiles
# Azure-Samples/traffic-manager-java-manage-profiles downloaded
# Downloading Azure-Samples/app-service-java-manage-web-apps
# Azure-Samples/app-service-java-manage-web-apps downloaded
# Downloading Azure-Samples/application-gateway-java-manage-simple-application-gateways
# Azure-Samples/application-gateway-java-manage-simple-application-gateways downloaded
# Downloading Azure-Samples/application-gateway-java-manage-application-gateways
# Azure-Samples/application-gateway-java-manage-application-gateways downloaded
# Downloading Azure-Samples/compute-java-create-virtual-machines-from-generalized-image-or-specialized-vhd
# Azure-Samples/compute-java-create-virtual-machines-from-generalized-image-or-specialized-vhd downloaded
# Downloading Azure-Samples/app-service-java-manage-data-connections-for-web-apps
# Azure-Samples/app-service-java-manage-data-connections-for-web-apps downloaded
# Downloading Azure-Samples/cdn-java-manage-cdn
# Azure-Samples/cdn-java-manage-cdn downloaded
# Downloading Azure-Samples/app-service-java-manage-web-apps-with-custom-domains
# Azure-Samples/app-service-java-manage-web-apps-with-custom-domains downloaded
# Downloading Azure-Samples/app-service-java-scale-web-apps
# Azure-Samples/app-service-java-scale-web-apps downloaded
# Downloading Azure-Samples/managed-disk-java-create-virtual-machine-using-custom-image
# Azure-Samples/managed-disk-java-create-virtual-machine-using-custom-image downloaded
# Downloading Azure-Samples/managed-disk-java-create-virtual-machine-using-custom-image-from-VHD
# Azure-Samples/managed-disk-java-create-virtual-machine-using-custom-image-from-VHD downloaded
# Downloading Azure-Samples/managed-disk-java-create-virtual-machine-using-specialized-disk-from-VHD
# Azure-Samples/managed-disk-java-create-virtual-machine-using-specialized-disk-from-VHD downloaded
# Downloading Azure-Samples/managed-disk-java-create-virtual-machine-using-specialized-disk-from-snapshot
# Azure-Samples/managed-disk-java-create-virtual-machine-using-specialized-disk-from-snapshot downloaded
# Downloading Azure-Samples/managed-disk-java-convert-existing-virtual-machines-to-use-managed-disks
# Azure-Samples/managed-disk-java-convert-existing-virtual-machines-to-use-managed-disks downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machine-with-unmanaged-disks
# Azure-Samples/compute-java-manage-virtual-machine-with-unmanaged-disks downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machine-scale-set-with-unmanaged-disks
# Azure-Samples/compute-java-manage-virtual-machine-scale-set-with-unmanaged-disks downloaded
# Downloading Azure-Samples/resources-java-deploy-virtual-machine-with-managed-disks-using-arm-template
# Azure-Samples/resources-java-deploy-virtual-machine-with-managed-disks-using-arm-template downloaded
# Downloading Azure-Samples/active-directory-b2c-android-native-appauth
# Azure-Samples/active-directory-b2c-android-native-appauth downloaded
# Downloading Azure-Samples/azure-mobile-apps-android-quickstart
# Azure-Samples/azure-mobile-apps-android-quickstart downloaded
# Downloading Azure-Samples/app-service-java-manage-web-apps-on-linux
# Azure-Samples/app-service-java-manage-web-apps-on-linux downloaded
# Downloading Azure-Samples/app-service-java-manage-authentication-for-web-apps
# Azure-Samples/app-service-java-manage-authentication-for-web-apps downloaded
# Downloading Azure-Samples/app-service-java-manage-web-apps-on-linux-with-custom-domains
# Azure-Samples/app-service-java-manage-web-apps-on-linux-with-custom-domains downloaded
# Downloading Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps-on-linux
# Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps-on-linux downloaded
# Downloading Azure-Samples/app-service-java-scale-web-apps-on-linux
# Azure-Samples/app-service-java-scale-web-apps-on-linux downloaded
# Downloading Azure-Samples/app-service-java-manage-storage-connections-for-web-apps-on-linux
# Azure-Samples/app-service-java-manage-storage-connections-for-web-apps-on-linux downloaded
# Downloading Azure-Samples/app-service-java-manage-data-connections-for-web-apps-on-linux
# Azure-Samples/app-service-java-manage-data-connections-for-web-apps-on-linux downloaded
# Downloading Azure-Samples/app-service-java-manage-functions
# Azure-Samples/app-service-java-manage-functions downloaded
# Downloading Azure-Samples/app-service-java-manage-functions-with-custom-domains
# Azure-Samples/app-service-java-manage-functions-with-custom-domains downloaded
# Downloading Azure-Samples/app-service-java-configure-deployment-sources-for-functions
# Azure-Samples/app-service-java-configure-deployment-sources-for-functions downloaded
# Downloading Azure-Samples/app-service-java-manage-authentication-for-functions
# Azure-Samples/app-service-java-manage-authentication-for-functions downloaded
# Downloading Azure-Samples/compute-java-manage-vm-async
# Azure-Samples/compute-java-manage-vm-async downloaded
# Downloading Azure-Samples/storage-java-manage-storage-accounts-async
# Azure-Samples/storage-java-manage-storage-accounts-async downloaded
# Downloading Azure-Samples/compute-java-manage-virtual-machine-scale-sets-async
# Azure-Samples/compute-java-manage-virtual-machine-scale-sets-async downloaded
# Downloading Azure-Samples/network-java-manage-virtual-network-async
# Azure-Samples/network-java-manage-virtual-network-async downloaded
# Downloading Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps-async
# Azure-Samples/app-service-java-configure-deployment-sources-for-web-apps-async downloaded
# Downloading Azure-Samples/service-bus-java-manage-queue-with-basic-features
# Azure-Samples/service-bus-java-manage-queue-with-basic-features downloaded
# Downloading Azure-Samples/service-bus-java-manage-publish-subscribe-with-basic-features
# Azure-Samples/service-bus-java-manage-publish-subscribe-with-basic-features downloaded
# Downloading Azure-Samples/service-bus-java-manage-with-claims-based-authorization
# Azure-Samples/service-bus-java-manage-with-claims-based-authorization downloaded
# Downloading Azure-Samples/service-bus-java-manage-publish-subscribe-with-advanced-features
# Azure-Samples/service-bus-java-manage-publish-subscribe-with-advanced-features downloaded
# Downloading Azure-Samples/service-bus-java-manage-queue-with-advanced-features
# Azure-Samples/service-bus-java-manage-queue-with-advanced-features downloaded
# Downloading Azure-Samples/ms-identity-android-native
# Azure-Samples/ms-identity-android-native downloaded
# Downloading Azure-Samples/active-directory-b2c-android-native-msal
# Azure-Samples/active-directory-b2c-android-native-msal downloaded
# Downloading Azure-Samples/azure-cosmos-db-graph-java-getting-started
# Azure-Samples/azure-cosmos-db-graph-java-getting-started downloaded
# Downloading Azure-Samples/azure-cosmos-db-mongodb-java-getting-started
# Azure-Samples/azure-cosmos-db-mongodb-java-getting-started downloaded
# Downloading Azure-Samples/hbase-phoenix-connection-pool
# Azure-Samples/hbase-phoenix-connection-pool downloaded
# Downloading Azure-Samples/aad-java-manage-service-principals
# Azure-Samples/aad-java-manage-service-principals downloaded
# Downloading Azure-Samples/aad-java-manage-passwords
# Azure-Samples/aad-java-manage-passwords downloaded
# Downloading Azure-Samples/acr-java-manage-azure-container-registry
# ...
# googlearchive/android-ElevationDrag downloaded
# Downloading googlearchive/android-ClippingBasic
# googlearchive/android-ClippingBasic downloaded
# Downloading googlearchive/androidtv-GameController
# googlearchive/androidtv-GameController downloaded
# Downloading googlearchive/androidtv-VisualGameController
# googlearchive/androidtv-VisualGameController downloaded
# Downloading googlearchive/android-JobScheduler
# googlearchive/android-JobScheduler downloaded
# Downloading googlearchive/android-NavigationDrawer
# googlearchive/android-NavigationDrawer downloaded
# Downloading googlearchive/androidtv-Leanback
# googlearchive/androidtv-Leanback downloaded
# Downloading googlearchive/identity-toolkit-android
# googlearchive/identity-toolkit-android downloaded
# Downloading googlearchive/tango-examples-java
# googlearchive/tango-examples-java downloaded
# Downloading googlearchive/appengine-java-vm-guestbook-extras
# googlearchive/appengine-java-vm-guestbook-extras downloaded
# Downloading googlearchive/android-fit
# googlearchive/android-fit downloaded
# Downloading googlearchive/firebase-login-demo-android
# googlearchive/firebase-login-demo-android downloaded
# Downloading googlearchive/android-FloatingActionButtonBasic
# googlearchive/android-FloatingActionButtonBasic downloaded
# Downloading googlearchive/android-PdfRendererBasic
# googlearchive/android-PdfRendererBasic downloaded
# Downloading googlearchive/android-ActionBarCompat-Basic
# googlearchive/android-ActionBarCompat-Basic downloaded
# Downloading googlearchive/android-ActionBarCompat-ListPopupMenu
# googlearchive/android-ActionBarCompat-ListPopupMenu downloaded
# Downloading googlearchive/android-ActionBarCompat-ShareActionProvider
# googlearchive/android-ActionBarCompat-ShareActionProvider downloaded
# Downloading googlearchive/android-ActionBarCompat-Styled
# googlearchive/android-ActionBarCompat-Styled downloaded
# Downloading googlearchive/android-ActivityInstrumentation
# googlearchive/android-ActivityInstrumentation downloaded
# Downloading googlearchive/android-AdvancedImmersiveMode
# googlearchive/android-AdvancedImmersiveMode downloaded
# Downloading googlearchive/android-AppRestrictions
# googlearchive/android-AppRestrictions downloaded
# Downloading googlearchive/android-BasicAccessibility
# googlearchive/android-BasicAccessibility downloaded
# Downloading googlearchive/android-BasicAndroidKeyStore
# googlearchive/android-BasicAndroidKeyStore downloaded
# Downloading googlearchive/android-BasicContactables
# googlearchive/android-BasicContactables downloaded
# Downloading googlearchive/android-BasicGestureDetect
# googlearchive/android-BasicGestureDetect downloaded
# Downloading googlearchive/android-BasicImmersiveMode
# googlearchive/android-BasicImmersiveMode downloaded
# Downloading googlearchive/android-BasicMediaDecoder
# googlearchive/android-BasicMediaDecoder downloaded
# Downloading googlearchive/android-BasicMediaRouter
# googlearchive/android-BasicMediaRouter downloaded
# Downloading googlearchive/android-BasicMultitouch
# googlearchive/android-BasicMultitouch downloaded
# Downloading googlearchive/android-BasicNetworking
# googlearchive/android-BasicNetworking downloaded
# Downloading googlearchive/android-BasicNotifications
# googlearchive/android-BasicNotifications downloaded
# Downloading googlearchive/android-BasicSyncAdapter
# googlearchive/android-BasicSyncAdapter downloaded
# Downloading googlearchive/android-BatchStepSensor
# googlearchive/android-BatchStepSensor downloaded
# Downloading googlearchive/android-BluetoothLeGatt
# googlearchive/android-BluetoothLeGatt downloaded
# Downloading googlearchive/android-BorderlessButtons
# googlearchive/android-BorderlessButtons downloaded
# Downloading googlearchive/android-CardEmulation
# googlearchive/android-CardEmulation downloaded
# Downloading googlearchive/android-CardReader
# googlearchive/android-CardReader downloaded
# Downloading googlearchive/android-CustomChoiceList
# googlearchive/android-CustomChoiceList downloaded
# Downloading googlearchive/android-CustomNotifications
# googlearchive/android-CustomNotifications downloaded
# Downloading googlearchive/android-DisplayingBitmaps
# googlearchive/android-DisplayingBitmaps downloaded
# Downloading googlearchive/android-DoneBar
# googlearchive/android-DoneBar downloaded
# Downloading googlearchive/android-HorizontalPaging
# googlearchive/android-HorizontalPaging downloaded
# Downloading googlearchive/android-ImmersiveMode
# googlearchive/android-ImmersiveMode downloaded
# Downloading googlearchive/android-MediaRecorder
# googlearchive/android-MediaRecorder downloaded
# Downloading googlearchive/android-MediaRouter
# googlearchive/android-MediaRouter downloaded
# Downloading googlearchive/android-NetworkConnect
# googlearchive/android-NetworkConnect downloaded
# Downloading googlearchive/android-RepeatingAlarm
# googlearchive/android-RepeatingAlarm downloaded
# Downloading googlearchive/android-SlidingTabsBasic
# googlearchive/android-SlidingTabsBasic downloaded
# Downloading googlearchive/android-SlidingTabsColors
# googlearchive/android-SlidingTabsColors downloaded
# Downloading googlearchive/android-StorageClient
# googlearchive/android-StorageClient downloaded
# Downloading googlearchive/android-StorageProvider
# googlearchive/android-StorageProvider downloaded
# Downloading googlearchive/android-SwipeRefreshLayoutBasic
# googlearchive/android-SwipeRefreshLayoutBasic downloaded
# Downloading googlearchive/android-SwipeRefreshListFragment
# googlearchive/android-SwipeRefreshListFragment downloaded
# Downloading googlearchive/android-SwipeRefreshMultipleViews
# googlearchive/android-SwipeRefreshMultipleViews downloaded
# Downloading googlearchive/android-TextLinkify
# googlearchive/android-TextLinkify downloaded
# Downloading googlearchive/android-TextSwitcher
# googlearchive/android-TextSwitcher downloaded
# Downloading googlearchive/Abelana-Android
# googlearchive/Abelana-Android downloaded
# Downloading googlearchive/android-google-accounts
# googlearchive/android-google-accounts downloaded
# Downloading googlearchive/android-BluetoothChat
# googlearchive/android-BluetoothChat downloaded
# Downloading googlearchive/android-MediaEffects
# googlearchive/android-MediaEffects downloaded
# Downloading googlearchive/android-SynchronizedNotifications
# googlearchive/android-SynchronizedNotifications downloaded
# Downloading googlearchive/android-CardView
# googlearchive/android-CardView downloaded
# Downloading googlearchive/android-DrawableTinting
# googlearchive/android-DrawableTinting downloaded
# Downloading googlearchive/android-LNotifications
# googlearchive/android-LNotifications downloaded
# Downloading googlearchive/android-RecyclerView
# googlearchive/android-RecyclerView downloaded
# Downloading googlearchive/drive-android-conflict
# googlearchive/drive-android-conflict downloaded
# Downloading googlearchive/android-AppRestrictionEnforcer
# googlearchive/android-AppRestrictionEnforcer downloaded
# Downloading googlearchive/android-AppRestrictionSchema
# googlearchive/android-AppRestrictionSchema downloaded
# Downloading googlearchive/android-DocumentCentricApps
# googlearchive/android-DocumentCentricApps downloaded
# Downloading googlearchive/android-DocumentCentricRelinquishIdentity
# googlearchive/android-DocumentCentricRelinquishIdentity downloaded
# Downloading googlearchive/android-HdrViewfinder
# googlearchive/android-HdrViewfinder downloaded
# Downloading googlearchive/android-DelayedConfirmation
# googlearchive/android-DelayedConfirmation downloaded
# Downloading googlearchive/android-ElizaChat
# googlearchive/android-ElizaChat downloaded
# Downloading googlearchive/android-FindMyPhone
# googlearchive/android-FindMyPhone downloaded
# Downloading googlearchive/android-Flashlight
# googlearchive/android-Flashlight downloaded
# Downloading googlearchive/android-Geofencing
# googlearchive/android-Geofencing downloaded
# Downloading googlearchive/android-GridViewPager
# googlearchive/android-GridViewPager downloaded
# Downloading googlearchive/android-Quiz
# googlearchive/android-Quiz downloaded
# Downloading googlearchive/android-RecipeAssistant
# googlearchive/android-RecipeAssistant downloaded
# Downloading googlearchive/android-SkeletonWearableApp
# googlearchive/android-SkeletonWearableApp downloaded
# Downloading googlearchive/android-Timer
# googlearchive/android-Timer downloaded
# Downloading googlearchive/android-WatchViewStub
# googlearchive/android-WatchViewStub downloaded
# Downloading googlearchive/android-MessagingService
# googlearchive/android-MessagingService downloaded
# Downloading googlearchive/android-MediaBrowserService
# googlearchive/android-MediaBrowserService downloaded
# Downloading googlearchive/android-DirectorySelection
# googlearchive/android-DirectorySelection downloaded
# Downloading googlearchive/android-ScreenCapture
# googlearchive/android-ScreenCapture downloaded
# Downloading googlearchive/bigquery-samples-python
# googlearchive/bigquery-samples-python downloaded
# Downloading googlearchive/android-nearby
# googlearchive/android-nearby downloaded
# Downloading googlearchive/MobileShoppingAssistant-sample
# googlearchive/MobileShoppingAssistant-sample downloaded
# Downloading googlearchive/android-codelab-watchface
# googlearchive/android-codelab-watchface downloaded
# Downloading googlearchive/android-ads
# googlearchive/android-ads downloaded
# Downloading googlearchive/drive-android-trash
# googlearchive/drive-android-trash downloaded
# Downloading googlearchive/android-play-places
# googlearchive/android-play-places downloaded
# Downloading googlearchive/attendee-checkin
# googlearchive/attendee-checkin downloaded
# Downloading googlearchive/android-BeamLargeFiles
# googlearchive/android-BeamLargeFiles downloaded
# Downloading googlearchive/android-DeviceOwner
# googlearchive/android-DeviceOwner downloaded
# Downloading googlearchive/android-NfcProvisioning
# googlearchive/android-NfcProvisioning downloaded
# Downloading googlearchive/caja
# googlearchive/caja downloaded
# Downloading googlearchive/androidtv-daydream
# googlearchive/androidtv-daydream downloaded
# Downloading googlearchive/android-BluetoothAdvertisements
# googlearchive/android-BluetoothAdvertisements downloaded
# Downloading googlearchive/friendlyping
# googlearchive/friendlyping downloaded
# Downloading googlearchive/android-credentials
# googlearchive/android-credentials downloaded
# Downloading googlearchive/androidpay-quickstart
# googlearchive/androidpay-quickstart downloaded
# Downloading googlearchive/android-FingerprintDialog
# googlearchive/android-FingerprintDialog downloaded
# Downloading googlearchive/android-ConfirmCredential
# googlearchive/android-ConfirmCredential downloaded
# Downloading googlearchive/android-RuntimePermissions
# googlearchive/android-RuntimePermissions downloaded
# Downloading googlearchive/android-AutoBackupForApps
# googlearchive/android-AutoBackupForApps downloaded
# Downloading googlearchive/android-ActiveNotifications
# googlearchive/android-ActiveNotifications downloaded
# Downloading googlearchive/android-Camera2Raw
# googlearchive/android-Camera2Raw downloaded
# Downloading googlearchive/surveys
# googlearchive/surveys downloaded
# Downloading googlearchive/abelana
# googlearchive/abelana downloaded
# Downloading googlearchive/easygoogle
# googlearchive/easygoogle downloaded
# Downloading googlearchive/android-DirectShare
# googlearchive/android-DirectShare downloaded
# Downloading googlearchive/android-MidiScope
# googlearchive/android-MidiScope downloaded
# Downloading googlearchive/android-MidiSynth
# googlearchive/android-MidiSynth downloaded
# Downloading googlearchive/cloud-debugger-gce-java-sample
# googlearchive/cloud-debugger-gce-java-sample downloaded
# Downloading googlearchive/android-AsymmetricFingerprintDialog
# googlearchive/android-AsymmetricFingerprintDialog downloaded
# Downloading googlearchive/android-WearCompanionLibrary
# googlearchive/android-WearCompanionLibrary downloaded
# Downloading googlearchive/android-WclDemoSample
# googlearchive/android-WclDemoSample downloaded
# Downloading googlearchive/custom-tabs-provider
# googlearchive/custom-tabs-provider downloaded
# Downloading googlearchive/intellij-protocol-buffer-editor-old
# googlearchive/intellij-protocol-buffer-editor-old downloaded
# Downloading googlearchive/android-gcmnetworkmanager
# googlearchive/android-gcmnetworkmanager downloaded
# Downloading googlearchive/android-ui-toolkit-demos
# googlearchive/android-ui-toolkit-demos downloaded
# Downloading googlearchive/android-MultiWindowPlayground
# googlearchive/android-MultiWindowPlayground downloaded
# Downloading googlearchive/android-DirectBoot
# googlearchive/android-DirectBoot downloaded
# Downloading googlearchive/android-ScopedDirectoryAccess
# googlearchive/android-ScopedDirectoryAccess downloaded
# Downloading googlearchive/two-token-sw
# googlearchive/two-token-sw downloaded
# Downloading googlearchive/leanback-showcase
# googlearchive/leanback-showcase downloaded
# Downloading googlearchive/firebase-jobdispatcher-android
# googlearchive/firebase-jobdispatcher-android downloaded
# Downloading googlearchive/android-play-awareness
# googlearchive/android-play-awareness downloaded
# Downloading googlearchive/science-journal
# googlearchive/science-journal downloaded
# Downloading googlearchive/apps-script-mobile-addons
# googlearchive/apps-script-mobile-addons downloaded
# Downloading googlearchive/tiger
# googlearchive/tiger downloaded
# Downloading googlearchive/android-AccelerometerPlay
# googlearchive/android-AccelerometerPlay downloaded
# Downloading googlearchive/play-apk-expansion
# googlearchive/play-apk-expansion downloaded
# Downloading googlearchive/android-Notifications
# googlearchive/android-Notifications downloaded
# Downloading googlearchive/android-AppShortcuts
# googlearchive/android-AppShortcuts downloaded
# Downloading googlearchive/android-CommitContentSampleIME
# googlearchive/android-CommitContentSampleIME downloaded
# Downloading googlearchive/android-CommitContentSampleApp
# googlearchive/android-CommitContentSampleApp downloaded
# Downloading googlearchive/android-DragAndDropAcrossApps
# googlearchive/android-DragAndDropAcrossApps downloaded
# Downloading googlearchive/android-ShareActionProvider
# googlearchive/android-ShareActionProvider downloaded
# Downloading googlearchive/android-ConstraintLayoutExamples
# googlearchive/android-ConstraintLayoutExamples downloaded
# Downloading googlearchive/android-ContentProviderPaging
# googlearchive/android-ContentProviderPaging downloaded
# Downloading googlearchive/android-PictureInPicture
# googlearchive/android-PictureInPicture downloaded
# Downloading googlearchive/android-AutofillFramework
# googlearchive/android-AutofillFramework downloaded
# Downloading googlearchive/android-NotificationChannels
# googlearchive/android-NotificationChannels downloaded
# Downloading googlearchive/digits-migration-helper-android
# googlearchive/digits-migration-helper-android downloaded
# Downloading googlearchive/android-instant-apps
# googlearchive/android-instant-apps downloaded
# Downloading googlearchive/android-EmojiCompat
# googlearchive/android-EmojiCompat downloaded
# Downloading googlearchive/android-DownloadableFonts
# googlearchive/android-DownloadableFonts downloaded
# Downloading googlearchive/android-topeka
# googlearchive/android-topeka downloaded
# Downloading googlearchive/friendlypix-android
# googlearchive/friendlypix-android downloaded
# Downloading googlearchive/android-fido
# googlearchive/android-fido downloaded
# Downloading googlearchive/android-SimpleMediaPlayer
# googlearchive/android-SimpleMediaPlayer downloaded
# Downloading googlearchive/account-transfer-api
# googlearchive/account-transfer-api downloaded
# Downloading googlearchive/leanback-assistant
# googlearchive/leanback-assistant downloaded
# Downloading googlearchive/leanback-homescreen-channels
# googlearchive/leanback-homescreen-channels downloaded
# Downloading googlearchive/chromeos-android-draganddrop-demo
# googlearchive/chromeos-android-draganddrop-demo downloaded
# Downloading googlearchive/cannonball-android
# googlearchive/cannonball-android downloaded
# Downloading googlearchive/android-WifiRttScan
# googlearchive/android-WifiRttScan downloaded
# Downloading googlearchive/android-SharingShortcuts
# googlearchive/android-SharingShortcuts downloaded
# Downloading googlearchive/android-DarkTheme
# googlearchive/android-DarkTheme downloaded
