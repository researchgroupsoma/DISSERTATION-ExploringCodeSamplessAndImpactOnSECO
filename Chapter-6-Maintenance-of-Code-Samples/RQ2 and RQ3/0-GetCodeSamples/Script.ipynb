# %%
pip install PyGithub
# Out:
# Requirement already satisfied: PyGithub in /opt/conda/lib/python3.8/site-packages (1.55)
# Requirement already satisfied: requests>=2.14.0 in /opt/conda/lib/python3.8/site-packages (from PyGithub) (2.25.1)
# Requirement already satisfied: pyjwt>=2.0 in /opt/conda/lib/python3.8/site-packages (from PyGithub) (2.0.0)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from PyGithub) (1.4.0)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.8/site-packages (from PyGithub) (1.2.12)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from pynacl>=1.4.0->PyGithub) (1.15.0)
# Requirement already satisfied: cffi>=1.4.1 in /opt/conda/lib/python3.8/site-packages (from pynacl>=1.4.0->PyGithub) (1.14.4)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub) (1.26.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub) (2020.12.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.8/site-packages (from deprecated->PyGithub) (1.12.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from github import Github
import pandas as pd

# %% [markdown]
# Here you need to put your GitHub Token. More information in: https://github.com/settings/tokens

# %%
g = Github("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")

# %%
def get_repos(organization_name):
    non_samples = ["googlearchive/digits-migration-helper-android", "googlearchive/play-apk-expansion", "googlearchive/tiger", "googlearchive/two-token-sw", "googlearchive/Abelana-Android", "googlearchive/solutions-mobile-backend-starter-java"]
    organization = g.get_organization(organization_name)
    repos = organization.get_repos("all")
    dataframe = pd.DataFrame(columns=["full_name", "created_at", "description", "forks_count", "language", "open_issues_count", "size", "stargazers_count", "subscribers_count", "updated_at", "watchers_count"])
    for repo in repos:
        if repo.full_name in non_samples:
            continue
        if(repo.language == "Java"):
            if(organization_name == "googlearchive"):
                if(not repo.description == None and not ("example" in repo.description.lower() or "sample" in repo.description.lower() or "example" in repo.full_name.lower() or "sample" in repo.full_name.lower() or "migrated" in repo.description.lower())):
                    continue
            elif(organization_name == "SAP-samples"):
                if(not repo.description == None and not ("cloud" in repo.description.lower() or "cloud" in repo.full_name.lower())):
                    continue
        else:
            continue
        dataframe = dataframe.append({"framework": organization_name,"full_name": repo.full_name, "created_at": repo.created_at, "description": repo.description, "forks_count": repo.forks_count, "language": repo.language, "open_issues_count": repo.open_issues_count, "size": repo.size, "stargazers_count": repo.stargazers_count, "subscribers_count": repo.subscribers_count, "updated_at": repo.updated_at, "watchers_count": repo.watchers_count}, ignore_index=True)
        print(g.get_rate_limit())
    return dataframe

# %%
frameworks = ["googlesamples", "aws-samples", "Azure-Samples", "spring-guides", "googlearchive", "spring-cloud-samples"]

# %%
dataframe = pd.DataFrame()
for framework in frameworks:
    dataframe = dataframe.append(get_repos(framework), ignore_index=True)
dataframe.to_csv("codesamples.csv", index=False)
# Out:
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4986, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4985, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4984, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4983, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4982, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4981, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4980, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4979, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4978, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4977, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4976, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4975, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4974, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4972, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4971, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4970, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4969, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4968, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4967, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4966, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4965, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4964, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4962, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4961, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4958, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4957, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4956, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4955, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4954, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4952, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4951, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4950, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4949, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4948, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4946, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4945, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4944, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4943, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4942, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4940, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4939, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4937, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4936, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4935, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4934, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4932, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4931, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4929, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4928, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4927, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4926, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4924, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4922, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4921, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4919, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4918, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4917, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4916, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4914, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4913, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4912, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4911, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4910, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4908, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4907, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4906, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4905, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4904, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=4903, limit=5000))
# RateLimit(core=Rate(reset=2021-08-24 00:11:01, remaining=